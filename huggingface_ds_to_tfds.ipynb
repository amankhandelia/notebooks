# %%
import os
os.environ["HF_HOME"] = "/dev/shm/huggingface"
os.environ["TFDS_DATA_DIR"] = "/dev/shm/tensorflow_datasets/"

# %%
from datasets import load_dataset

desi_dataset = load_dataset("desiai/samachaar", num_proc=32)
# Out:
# Found cached dataset parquet (/dev/shm/huggingface/datasets/desiai___parquet/desiai--samachaar-2630ec8002ac4f2b/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from tensorflow_datasets.core.dataset_builders import huggingface_dataset_builder
builder = huggingface_dataset_builder.HuggingfaceDatasetBuilder(
    hf_repo_id="desiai/samachaar",
    hf_num_proc=32,
)
builder.download_and_prepare()
# Out:
# 2023-05-17 16:04:11.663442: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-17 16:04:11.713846: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-17 16:04:11.715371: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-17 16:04:12.543203: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# WARNING:datasets.builder:Found cached dataset parquet (/dev/shm/huggingface/datasets/desiai___parquet/desiai--samachaar-2630ec8002ac4f2b/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
# ...

# %%
train_ds = builder.as_dataset(split='train', read_config = None, shuffle_files=False)
# Out:
# 2023-05-03 17:34:48.821992: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-03 17:34:48.874390: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-03 17:34:48.875094: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-03 17:34:49.681693: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
data = train_ds.take(10)

# %%
for item in data:
    print(item)
# Out:
# {'Body': <tf.Tensor: shape=(), dtype=string, numpy=b'<p><b>\xe0\xa4\xaa\xe0\xa4\xa4\xe0\xa5\x8d\xe0\xa4\xb0\xe0\xa4\xbf\xe0\xa4\x95\xe0\xa4\xbe \xe0\xa4\xa8\xe0\xa5\x8d\xe0\xa4\xaf\xe0\xa5\x82\xe0\xa4\x9c \xe0\xa4\xa8\xe0\xa5\x87\xe0\xa4\x9f\xe0\xa4\xb5\xe0\xa4\xb0\xe0\xa5\x8d\xe0\xa4\x95\n</b></p><p>patrika.com\n</p><p><b>\xe0\xa4\x9c\xe0\xa5\x88\xe0\xa4\xb8\xe0\xa4\xb2\xe0\xa4\xae\xe0\xa5\x87\xe0\xa4\xb0. </b>\xe0\xa4\x95\xe0\xa5\x87\xe0\xa4\x82\xe0\xa4\xa6\xe0\xa5\x8d\xe0\xa4\xb0\xe0\xa5\x80\xe0\xa4\xaf \xe0\xa4\xb5\xe0\xa4\xbf\xe0\xa4\xa6\xe0\xa5\x8d\xe0\xa4\xaf\xe0\xa4\xbe\xe0\xa4\xb2\xe0\xa4\xaf \xe0\xa4\xb5\xe0\xa4\xbe\xe0\xa4\xaf\xe0\xa5\x81\xe0\xa4\xb8\xe0\xa5\x87\xe0\xa4\xa8\xe0\xa4\xbe \xe0\xa4\x9c\xe0\xa5\x88\xe0\xa4\xb8\xe0\xa4\xb2\xe0\xa4\xae\xe0\xa5\x87\xe0\xa4\xb0 \xe0\xa4\xae\xe0\xa5\x87\xe0\xa4\x82 \xe0\xa4\x97\xe0\xa4\xbe\xe0\xa4\x82\xe0\xa4\xa7\xe0\xa5\x80 \xe0\xa4\x9c\xe0\xa4\xaf\xe0\xa4\x82\xe0\xa4\xa4\xe0\xa5\x80 \xe0\xa4\xa7\xe0\xa5\x82\xe0\xa4\xae\xe0\xa4\xa7
# ...
